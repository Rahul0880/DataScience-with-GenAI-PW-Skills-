# %% [markdown]
# #1. What is Deep Learning? Briefly describe how it evolved and how it differs
# from traditional machine learning.
# Answer:Deep Learning is a subfield of machine learning that uses artificial neural networks with many layers (“deep” networks) to automatically learn patterns from large amounts of data. It is especially effective for tasks like image recognition, speech processing, language translation, and game playing.
#
# Evolution of Deep Learning
#
# 1940s–1980s: Early ideas of artificial neurons (e.g., perceptron) and basic neural networks were proposed, but limited computing power and data restricted progress.
#
# 1990s–2000s: Traditional machine learning methods (like decision trees, SVMs) became dominant because they worked well with smaller datasets.
#
# 2010s–present: Deep learning surged due to:
#
# Availability of big data
#
# Powerful GPUs/TPUs
#
# Improved algorithms (e.g., backpropagation, ReLU, dropout)
#
# Breakthroughs in image and speech recognition
#
# Difference Between Deep Learning and Traditional Machine Learning
# Aspect	Traditional Machine Learning	Deep Learning
# Feature extraction	Done manually by humans	Learned automatically from data
# Model complexity	Shallow models	Deep, multi-layer neural networks
# Data requirement	Works with smaller datasets	Requires large amounts of data
# Performance	Good for structured data	Excellent for unstructured data (images, audio, text)
# Interpretability	Easier to interpret	Often a “black box”

# %% [markdown]
# #2.Explain the basic architecture and functioning of a Perceptron. What are its
# limitations?
# Answer:A Perceptron is the simplest form of an artificial neural network and is used for binary classification.
#
# Components:
#
# Inputs (x₁, x₂, …, xₙ): Feature values fed into the model.
#
# Weights (w₁, w₂, …, wₙ): Each input has an associated weight that represents its importance.
#
# Bias (b): A constant added to shift the decision boundary.
#
# Weighted Sum:
#
# 𝑧
# =
# ∑
# 𝑖
# =
# 1
# 𝑛
# 𝑤
# 𝑖
# 𝑥
# 𝑖
# +
# 𝑏
# z=
# i=1
# ∑
# n
# 	​
#
# w
# i
# 	​
#
# x
# i
# 	​
#
# +b
#
# Activation Function: Typically a step (threshold) function that produces the output.
#
# 𝑦
# =
# {
# 1
# ,
#
# if
# 𝑧
# ≥
# 0
#
#
# 0
# ,
#
# if
# 𝑧
# <
# 0
# y={
# 1,
# 0,
# 	​
#
# if z≥0
# if z<0
# 	​
#
# Functioning of a Perceptron
#
# Input values are multiplied by their corresponding weights.
#
# The weighted inputs are summed along with the bias.
#
# The activation function determines the final output (0 or 1).
#
# During training, weights are updated using the Perceptron Learning Rule based on classification errors:
#
# 𝑤
# 𝑖
# =
# 𝑤
# 𝑖
# +
# 𝜂
# (
# 𝑦
# true
# −
# 𝑦
# pred
# )
# 𝑥
# 𝑖
# w
# i
# 	​
#
# =w
# i
# 	​
#
# +η(y
# true
# 	​
#
# −y
# pred
# 	​
#
# )x
# i
# 	​
#
#
# where
# 𝜂
# η is the learning rate.
#
# Limitations of a Perceptron
#
# Only linearly separable problems:
# A single-layer perceptron cannot solve non-linear problems (e.g., XOR problem).
#
# Binary output only:
# It handles only two classes.
#
# No hidden layers:
# Lacks the ability to learn complex patterns.
#
# Limited activation function:
# The step function is not differentiable, making it unsuitable for gradient-based optimization in deeper networks.

# %% [markdown]
# #3. Describe the purpose of activation function in neural networks. Compare
# Sigmoid, ReLU, and Tanh functions.
# Answer:Purpose of Activation Functions in Neural Networks
#
# An activation function introduces non-linearity into a neural network. Without activation functions, a neural network would behave like a linear model regardless of the number of layers. Activation functions enable networks to:
#
# Learn complex and non-linear relationships
#
# Decide whether a neuron should be activated (fire)
#
# Improve the network’s ability to model real-world data such as images, speech, and text
#
# Comparison of Sigmoid, Tanh, and ReLU Activation Functions
# Feature	Sigmoid	Tanh	ReLU
# Formula
# 𝜎
# (
# 𝑥
# )
# =
# 1
# 1
# +
# 𝑒
# −
# 𝑥
# σ(x)=
# 1+e
# −x
# 1
# 	​
#
#
# tanh
# ⁡
# (
# 𝑥
# )
# =
# 𝑒
# 𝑥
# −
# 𝑒
# −
# 𝑥
# 𝑒
# 𝑥
# +
# 𝑒
# −
# 𝑥
# tanh(x)=
# e
# x
# +e
# −x
# e
# x
# −e
# −x
# 	​
#
#
# 𝑓
# (
# 𝑥
# )
# =
# max
# ⁡
# (
# 0
# ,
# 𝑥
# )
# f(x)=max(0,x)
# Output Range	(0, 1)	(−1, 1)	[0, ∞)
# Zero-centered	❌ No	✅ Yes	❌ No
# Non-linearity	Smooth	Smooth	Piecewise linear
# Vanishing gradient	High risk	Lower than sigmoid	Very low for
# 𝑥
# >
# 0
# x>0
# Computational cost	Higher (exp function)	Higher (exp function)	Very low
# Common usage	Output layer (binary classification)	Hidden layers (older networks)	Hidden layers (modern deep networks)
# Key Differences Explained
#
# Sigmoid:
# Compresses inputs into probabilities, but suffers from vanishing gradients, slowing learning in deep networks.
#
# Tanh:
# Similar to sigmoid but zero-centered, which often leads to faster convergence than sigmoid.
#
# ReLU:
# Simple and efficient, allows faster training and is the most widely used activation function in deep learning today. However, it can suffer from the “dying ReLU” problem when neurons output zero permanently.

# %% [markdown]
# #4.What is the difference between Loss function and Cost function in neural
# networks? Provide examples.
# Answer:Difference Between Loss Function and Cost Function in Neural Networks
#
# Although the terms are sometimes used interchangeably, there is a conceptual difference between them.
#
# Loss Function
#
# A loss function measures the error for a single training example.
# It tells us how far the model’s prediction is from the true value for one data point.
#
# Purpose:
#
# Evaluates performance on one sample
#
# Guides weight updates during training
#
# Examples:
#
# Mean Squared Error (MSE) loss (single sample):
#
# 𝐿
# (
# 𝑦
# ,
# 𝑦
# ^
# )
# =
# (
# 𝑦
# −
# 𝑦
# ^
# )
# 2
# L(y,
# y
# ^
# 	​
#
# )=(y−
# y
# ^
# 	​
#
# )
# 2
#
# Binary Cross-Entropy loss:
#
# 𝐿
# (
# 𝑦
# ,
# 𝑦
# ^
# )
# =
# −
# [
# 𝑦
# log
# ⁡
# (
# 𝑦
# ^
# )
# +
# (
# 1
# −
# 𝑦
# )
# log
# ⁡
# (
# 1
# −
# 𝑦
# ^
# )
# ]
# L(y,
# y
# ^
# 	​
#
# )=−[ylog(
# y
# ^
# 	​
#
# )+(1−y)log(1−
# y
# ^
# 	​
#
# )]
# Cost Function
#
# A cost function is the average (or total) loss over the entire training dataset (or a batch).
# It represents the overall performance of the model.
#
# Purpose:
#
# Evaluates how well the model performs on all training data
#
# Used as the objective function to minimize during training
#
# Examples:
#
# Mean Squared Error cost:
#
# 𝐽
# =
# 1
# 𝑁
# ∑
# 𝑖
# =
# 1
# 𝑁
# (
# 𝑦
# 𝑖
# −
# 𝑦
# ^
# 𝑖
# )
# 2
# J=
# N
# 1
# 	​
#
# i=1
# ∑
# N
# 	​
#
# (y
# i
# 	​
#
# −
# y
# ^
# 	​
#
# i
# 	​
#
# )
# 2
#
# Cross-Entropy cost function:
#
# 𝐽
# =
# −
# 1
# 𝑁
# ∑
# 𝑖
# =
# 1
# 𝑁
# [
# 𝑦
# 𝑖
# log
# ⁡
# (
# 𝑦
# ^
# 𝑖
# )
# +
# (
# 1
# −
# 𝑦
# 𝑖
# )
# log
# ⁡
# (
# 1
# −
# 𝑦
# ^
# 𝑖
# )
# ]
# J=−
# N
# 1
# 	​
#
# i=1
# ∑
# N
# 	​
#
# [y
# i
# 	​
#
# log(
# y
# ^
# 	​
#
# i
# 	​
#
# )+(1−y
# i
# 	​
#
# )log(1−
# y
# ^
# 	​
#
# i
# 	​
#
# )]
# Key Differences at a Glance
# Aspect	Loss Function	Cost Function
# Scope	Single training example	Entire dataset or batch
# Measures	Individual prediction error	Overall model error
# Usage	Per-sample evaluation	Optimization objective
# Notation
# 𝐿
# (
# ⋅
# )
# L(⋅)
# 𝐽
# (
# ⋅
# )
# J(⋅)

# %% [markdown]
# #5.What is the role of optimizers in neural networks? Compare Gradient
# Descent, Adam, and RMSprop.
# answer:Role of Optimizers in Neural Networks
#
# An optimizer is an algorithm used to update the weights and biases of a neural network during training so as to minimize the loss (cost) function.
#
# Main roles of optimizers:
#
# Determine how much and in which direction model parameters should be updated
#
# Improve training speed and convergence
#
# Help avoid issues like slow learning, oscillations, or getting stuck in poor minima
#
# Optimizers use the gradients computed by backpropagation to adjust parameters.
#
# Comparison of Gradient Descent, RMSprop, and Adam
# Feature	Gradient Descent	RMSprop	Adam
# Learning rate	Fixed (or manually scheduled)	Adaptive	Adaptive
# Update rule	Uses same learning rate for all parameters	Adjusts learning rate per parameter	Combines momentum + adaptive learning rates
# Memory of past gradients	❌ No	✅ Yes (moving average of squared gradients)	✅ Yes (1st & 2nd moment estimates)
# Convergence speed	Slow	Faster than GD	Fastest in most cases
# Stability	Can oscillate	More stable	Very stable
# Best suited for	Simple problems, convex loss	Non-stationary objectives	Deep & large-scale networks
# Brief Explanation of Each Optimizer
# 1. Gradient Descent
#
# Updates weights in the direction of the negative gradient
#
# Simple and easy to implement
#
# Sensitive to learning rate choice
#
# Variants: Batch GD, Stochastic GD (SGD), Mini-batch GD
#
# Update rule:
#
# 𝑤
# =
# 𝑤
# −
# 𝜂
# ∇
# 𝐽
# (
# 𝑤
# )
# w=w−η∇J(w)
# 2. RMSprop (Root Mean Square Propagation)
#
# Maintains a moving average of squared gradients
#
# Reduces learning rate for parameters with large gradients
#
# Works well for non-stationary problems
#
# Update rule (simplified):
#
# 𝑣
# 𝑡
# =
# 𝛽
# 𝑣
# 𝑡
# −
# 1
# +
# (
# 1
# −
# 𝛽
# )
# (
# ∇
# 𝐽
# )
# 2
# v
# t
# 	​
#
# =βv
# t−1
# 	​
#
# +(1−β)(∇J)
# 2
# 𝑤
# =
# 𝑤
# −
# 𝜂
# 𝑣
# 𝑡
# +
# 𝜖
# ∇
# 𝐽
# w=w−
# v
# t
# 	​
#
# +ϵ
# 	​
#
# η
# 	​
#
# ∇J
# 3. Adam (Adaptive Moment Estimation)
#
# Combines Momentum (1st moment) and RMSprop (2nd moment)
#
# Uses bias correction for better early training
#
# Most widely used optimizer in deep learning
#
# Update rule (simplified):
#
# 𝑚
# 𝑡
# =
# 𝛽
# 1
# 𝑚
# 𝑡
# −
# 1
# +
# (
# 1
# −
# 𝛽
# 1
# )
# ∇
# 𝐽
# m
# t
# 	​
#
# =β
# 1
# 	​
#
# m
# t−1
# 	​
#
# +(1−β
# 1
# 	​
#
# )∇J
# 𝑣
# 𝑡
# =
# 𝛽
# 2
# 𝑣
# 𝑡
# −
# 1
# +
# (
# 1
# −
# 𝛽
# 2
# )
# (
# ∇
# 𝐽
# )
# 2
# v
# t
# 	​
#
# =β
# 2
# 	​
#
# v
# t−1
# 	​
#
# +(1−β
# 2
# 	​
#
# )(∇J)
# 2

# %% [markdown]
# #6. Write a Python program to implement a single-layer perceptron from
# scratch using NumPy to solve the logical AND gate.

# %%
import numpy as np

# AND gate dataset
# Inputs
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Outputs
y = np.array([0, 0, 0, 1])

# Initialize weights and bias
weights = np.zeros(X.shape[1])
bias = 0
learning_rate = 0.1
epochs = 10

# Step activation function
def step_function(z):
    return 1 if z >= 0 else 0

# Training the perceptron
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}")
    for i in range(len(X)):
        z = np.dot(X[i], weights) + bias
        y_pred = step_function(z)
        error = y[i] - y_pred

        # Update weights and bias
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Input: {X[i]}, Prediction: {y_pred}, Error: {error}")
    print()

# Testing the perceptron
print("Final Weights:", weights)
print("Final Bias:", bias)
print("\nAND Gate Predictions:")
for i in range(len(X)):
    z = np.dot(X[i], weights) + bias
    print(f"Input: {X[i]} Output: {step_function(z)}")
# Out:
# Epoch 1
# Input: [0 0], Prediction: 1, Error: -1
# Input: [0 1], Prediction: 0, Error: 0
# Input: [1 0], Prediction: 0, Error: 0
# Input: [1 1], Prediction: 0, Error: 1
#
# Epoch 2
# Input: [0 0], Prediction: 1, Error: -1
# Input: [0 1], Prediction: 1, Error: -1
# Input: [1 0], Prediction: 0, Error: 0
# Input: [1 1], Prediction: 0, Error: 1
#
# Epoch 3
# Input: [0 0], Prediction: 0, Error: 0
# Input: [0 1], Prediction: 1, Error: -1
# Input: [1 0], Prediction: 1, Error: -1
# Input: [1 1], Prediction: 0, Error: 1
#
# Epoch 4
# Input: [0 0], Prediction: 0, Error: 0
# Input: [0 1], Prediction: 0, Error: 0
# Input: [1 0], Prediction: 0, Error: 0
# Input: [1 1], Prediction: 1, Error: 0
#
# Epoch 5
# Input: [0 0], Prediction: 0, Error: 0
# Input: [0 1], Prediction: 0, Error: 0
# Input: [1 0], Prediction: 0, Error: 0
# Input: [1 1], Prediction: 1, Error: 0
#
# Epoch 6
# Input: [0 0], Prediction: 0, Error: 0
# Input: [0 1], Prediction: 0, Error: 0
# Input: [1 0], Prediction: 0, Error: 0
# ...

# %% [markdown]
# #7.Implement and visualize Sigmoid, ReLU, and Tanh activation functions
# using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate input values
x = np.linspace(-10, 10, 400)

# Activation functions
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

# Compute outputs
y_sigmoid = sigmoid(x)
y_relu = relu(x)
y_tanh = tanh(x)

# Plot the activation functions
plt.figure(figsize=(10, 6))

plt.plot(x, y_sigmoid, label="Sigmoid", linewidth=2)
plt.plot(x, y_relu, label="ReLU", linewidth=2)
plt.plot(x, y_tanh, label="Tanh", linewidth=2)

plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

plt.title("Activation Functions Visualization")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# #8.Use Keras to build and train a simple multilayer neural network on the
# MNIST digits dataset. Print the training accuracy.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values (0–255 → 0–1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the neural network model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    verbose=1
)

# Print training accuracy
training_accuracy = history.history['accuracy'][-1]
print(f"\nTraining Accuracy: {training_accuracy * 100:.2f}%")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8751 - loss: 0.4237
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9689 - loss: 0.1044
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9785 - loss: 0.0728
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9829 - loss: 0.0548
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9879 - loss: 0.0394
#
# Training Accuracy: 98.63%

# %% [markdown]
# #9.Visualize the loss and accuracy curves for a neural network model trained
# on the Fashion MNIST dataset. Interpret the training behavior.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load Fashion-MNIST dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalize data
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Plot loss curves
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot accuracy curves
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7750 - loss: 0.6403 - val_accuracy: 0.8502 - val_loss: 0.4186
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8660 - loss: 0.3722 - val_accuracy: 0.8594 - val_loss: 0.3874
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8773 - loss: 0.3376 - val_accuracy: 0.8635 - val_loss: 0.3808
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8843 - loss: 0.3141 - val_accuracy: 0.8691 - val_loss: 0.3596
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8905 - loss: 0.2916 - val_accuracy: 0.8578 - val_loss: 0.3878
# Epoch 6/10
# ...

# %% [markdown]
# #10.You are working on a project for a bank that wants to automatically detect
# fraudulent transactions. The dataset is large, imbalanced, and contains structured
# features like transaction amount, merchant ID, and customer location. The goal is to
# classify each transaction as fraudulent or legitimate.
# Explain your real-time data science workflow:
# ● How would you design a deep learning model (perceptron or multilayer NN)?
# ● Which activation function and loss function would you use, and why?
# ● How would you train and evaluate the model, considering class imbalance?
# ● Which optimizer would be suitable, and how would you prevent overfitting?

# %% [markdown]
# Below is a clear real-time data science workflow for fraud detection, followed by a representative Python/Keras example that demonstrates the ideas (using a synthetic imbalanced dataset to mimic bank transactions).
#
# 1. Model Design (Perceptron vs Multilayer Neural Network)
#
# Choice: Multilayer Neural Network (MLP)
#
# A single-layer perceptron is too simple for fraud detection.
#
# Fraud patterns are non-linear and depend on interactions between features (amount, merchant, location, time, etc.).
#
# A multilayer neural network can learn complex relationships in structured/tabular data.
#
# Typical Architecture
#
# Input layer: structured features
#
# 2–3 hidden Dense layers
#
# Output layer: 1 neuron (fraud / not fraud)
#
# 2. Activation Function & Loss Function
# Activation Functions
#
# Hidden layers: ReLU
#
# Fast convergence
#
# Avoids vanishing gradients
#
# Output layer: Sigmoid
#
# Outputs probability ∈ [0,1] for binary classification
#
# Loss Function
#
# Binary Cross-Entropy
#
# Best suited for binary classification
#
# Penalizes confident wrong predictions heavily
#
# With imbalance: use class weights or focal loss
#
# 3. Training & Evaluation (Handling Class Imbalance)
# Class Imbalance Strategy
#
# Fraud cases are rare (e.g., 1–2%)
#
# Techniques:
#
# Class weights (preferred for deep learning)
#
# Oversampling (SMOTE) or undersampling
#
# Evaluate using:
#
# Precision
#
# Recall
#
# F1-score
#
# ROC-AUC
# (Accuracy alone is misleading)
#
# 4. Optimizer & Overfitting Prevention
# Optimizer
#
# Adam
#
# Adaptive learning rate
#
# Fast and stable for large datasets
#
# Industry standard for fraud detection models
#
# Preventing Overfitting
#
# Dropout layers
#
# Early stopping
#
# L2 regularization
#
# Validation monitoring (loss & recall)
#
# 5. Example Python Code (Keras – Imbalanced Fraud-like Data)
#
# This code simulates a fraud dataset and demonstrates best practices.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

# Simulate imbalanced transaction dataset
np.random.seed(42)
X = np.random.rand(10000, 10)          # 10 structured features
y = np.zeros(10000)
y[:300] = 1                            # 3% fraud cases
np.random.shuffle(y)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Compute class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# Build model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X.shape[1],)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()]
)

# Early stopping
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# Train model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=20,
    batch_size=64,
    class_weight=class_weights,
    callbacks=[early_stop],
    verbose=1
)

# Evaluate model
loss, acc, recall, precision = model.evaluate(X_test, y_test, verbose=0)

print(f"Test Accuracy: {acc:.4f}")
print(f"Test Recall (Fraud Detection): {recall:.4f}")
print(f"Test Precision: {precision:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6952 - loss: 0.7491 - precision: 0.0298 - recall: 0.2618 - val_accuracy: 0.4050 - val_loss: 0.7091 - val_precision: 0.0292 - val_recall: 0.5833
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6025 - loss: 0.6734 - precision: 0.0323 - recall: 0.4453 - val_accuracy: 0.1595 - val_loss: 0.7495 - val_precision: 0.0301 - val_recall: 0.8667
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4882 - loss: 0.7082 - precision: 0.0312 - recall: 0.5244 - val_accuracy: 0.2825 - val_loss: 0.7226 - val_precision: 0.0307 - val_recall: 0.7500
# Epoch 4/20
# ...
